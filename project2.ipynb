# %%
import pandas as pd

# %%
df=pd.read_csv('Sleep_Efficiency.csv')
df
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 0      1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 1      2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00
# 2      3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3      4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 4      5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00
# ..   ...  ...     ...                  ...                  ...
# 447  448   27  Female  2021-11-13 22:00:00  2021-11-13 05:30:00
# 448  449   52    Male  2021-03-31 21:00:00  2021-03-31 03:00:00
# 449  450   40  Female  2021-09-07 23:00:00  2021-09-07 07:30:00
# 450  451   45    Male  2021-07-29 21:00:00  2021-07-29 04:00:00
# 451  452   18    Male  2021-03-17 02:30:00  2021-03-17 10:00:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 0               6.0              0.88                    18
# 1               7.0              0.66                    19
# ...

# %%
df.corr()
# Out:
# /var/folders/8q/07h3fzrs3z17bz7zwkw7jd4h0000gn/T/ipykernel_29923/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                               ID       Age  Sleep duration  Sleep efficiency  \
# ID                      1.000000  0.021310        0.014333         -0.025624
# Age                     0.021310  1.000000       -0.062462          0.098357
# Sleep duration          0.014333 -0.062462        1.000000         -0.027467
# Sleep efficiency       -0.025624  0.098357       -0.027467          1.000000
# REM sleep percentage    0.051636  0.042091       -0.015940          0.062362
# Deep sleep percentage  -0.047300  0.021730       -0.037304          0.787335
# Light sleep percentage  0.036463 -0.031905        0.041804         -0.819204
# ...

# %%
dfmale=df[df.Gender=="Male"]

# %%
dffemale=df[df.Gender=="Female"]

# %%
dfmale
# Out:
#       ID  Age Gender              Bedtime          Wakeup time  \
# 1      2   69   Male  2021-12-05 02:00:00  2021-12-05 09:00:00
# 4      5   57   Male  2021-03-13 01:00:00  2021-03-13 09:00:00
# 7      8   53   Male  2021-08-16 00:30:00  2021-08-16 10:30:00
# 10    11   50   Male  2021-02-28 00:30:00  2021-02-28 08:30:00
# 11    12   55   Male  2021-03-10 22:30:00  2021-03-10 06:00:00
# ..   ...  ...    ...                  ...                  ...
# 444  445   24   Male  2021-05-07 00:00:00  2021-05-07 07:30:00
# 446  447   23   Male  2021-04-21 00:00:00  2021-04-21 07:00:00
# 448  449   52   Male  2021-03-31 21:00:00  2021-03-31 03:00:00
# 450  451   45   Male  2021-07-29 21:00:00  2021-07-29 04:00:00
# 451  452   18   Male  2021-03-17 02:30:00  2021-03-17 10:00:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 1               7.0              0.66                    19
# 4               8.0              0.76                    27
# ...

# %%
dfmale['Sleep duration'].mean()
# Out:
# 7.427631578947368

# %%
dfmale['Sleep duration'].hist()
# Out:
# <Axes: >

# %%
dffemale
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 0      1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 2      3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3      4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 5      6   36  Female  2021-07-01 21:00:00  2021-07-01 04:30:00
# 6      7   27  Female  2021-07-21 21:00:00  2021-07-21 03:00:00
# ..   ...  ...     ...                  ...                  ...
# 442  443   27  Female  2021-02-06 01:30:00  2021-02-06 08:30:00
# 443  444   65  Female  2021-09-05 02:00:00  2021-09-05 09:30:00
# 445  446   30  Female  2021-11-16 23:00:00  2021-11-16 06:30:00
# 447  448   27  Female  2021-11-13 22:00:00  2021-11-13 05:30:00
# 449  450   40  Female  2021-09-07 23:00:00  2021-09-07 07:30:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 0               6.0              0.88                    18
# 2               8.0              0.89                    20
# ...

# %%
dffemale['Sleep duration'].mean()
# Out:
# 7.504464285714286

# %%
dffemale['Sleep duration'].hist()
# Out:
# <Axes: >

# %%
dfage=df[df.Age<=30]
dfage
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 6      7   27  Female  2021-07-21 21:00:00  2021-07-21 03:00:00
# 9     10   11  Female  2021-09-16 01:00:00  2021-09-16 10:00:00
# 12    13   30  Female  2021-08-07 02:30:00  2021-08-07 11:30:00
# 13    14   28    Male  2021-02-25 01:00:00  2021-02-25 09:30:00
# 16    17   21  Female  2021-03-24 01:00:00  2021-03-24 08:00:00
# ..   ...  ...     ...                  ...                  ...
# 444  445   24    Male  2021-05-07 00:00:00  2021-05-07 07:30:00
# 445  446   30  Female  2021-11-16 23:00:00  2021-11-16 06:30:00
# 446  447   23    Male  2021-04-21 00:00:00  2021-04-21 07:00:00
# 447  448   27  Female  2021-11-13 22:00:00  2021-11-13 05:30:00
# 451  452   18    Male  2021-03-17 02:30:00  2021-03-17 10:00:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 6               6.0              0.54                    28
# 9               9.0              0.55                    18
# ...

# %%
dfage['Sleep duration'].mean()
# Out:
# 7.540441176470588

# %%
dfage['Sleep duration'].hist()
# Out:
# <Axes: >

# %%
dfage2=df[df.Age>30]
dfage2
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 0      1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 1      2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00
# 2      3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3      4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 4      5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00
# ..   ...  ...     ...                  ...                  ...
# 441  442   46    Male  2021-03-30 00:00:00  2021-03-30 09:00:00
# 443  444   65  Female  2021-09-05 02:00:00  2021-09-05 09:30:00
# 448  449   52    Male  2021-03-31 21:00:00  2021-03-31 03:00:00
# 449  450   40  Female  2021-09-07 23:00:00  2021-09-07 07:30:00
# 450  451   45    Male  2021-07-29 21:00:00  2021-07-29 04:00:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 0               6.0              0.88                    18
# 1               7.0              0.66                    19
# ...

# %%
dfage2['Sleep duration'].mean()
# Out:
# 7.4335443037974684

# %%
dfage2['Sleep duration'].hist()
# Out:
# <Axes: >
